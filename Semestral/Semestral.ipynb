# %%
import numpy as np
import pandas as pd
import json

# %%
study_results = pd.read_json("serendipity_task/df_iteration_impressions_selections_serendipities.json")
questionnaire_results = pd.read_json("serendipity_task/after_block_questionnaire.json")

study_results["block"] = study_results["iteration"] // 6
study_results["block_iteration"] = study_results["iteration"] % 6

study_results.head(3)
# Out:
#                                                     9706   \
# plot    [A special bond develops between plus-sized in...
# cast    [Scott Adsit, Ryan Potter, Daniel Henney, T.J....
# genres  [Animation, Action, Adventure, Comedy, Drama, ...
# rating                                                7.8
# year                                                 2014
#
#                                                     2709   \
# plot    [In 1945, immediately following the end of Sec...
# cast    [Nicole Kidman, Fionnula Flanagan, Christopher...
# genres                        [Horror, Mystery, Thriller]
# rating                                                7.6
# year                                                 2001
#
#                                                     3216   \
# plot    [Barely 21 yet, Frank is a skilled forger who ...
# cast    [Leonardo DiCaprio, Tom Hanks, Christopher Wal...
# genres                          [Biography, Crime, Drama]
# rating                                                8.1
# year                                                 2002
#
#                                                     2197   \
# plot    [Male nurse Greg Focker meets his girlfriend's...
# cast    [Robert De Niro, Ben Stiller, Teri Polo, Blyth...
# genres                                  [Comedy, Romance]
# rating                                                7.0
# year                                                 2000
#
#                                                     9493   \
# plot    [A promising young drummer enrolls at a cut-th...
# cast    [Miles Teller, J.K. Simmons, Paul Reiser, Meli...
# genres                                     [Drama, Music]
# rating                                                8.5
# year                                                 2014
#
#                                                     3968   \
# plot    [While examining the influence of the fast foo...
# cast    [Chemeeka Walker, Dania Abu-Rmaileh, Amanda Ke...
# genres                                      [Documentary]
# rating                                                7.2
# year                                                 2004
#
#                                                     2095   \
# plot    [Peaceful farmer Benjamin Martin is driven to ...
# cast    [Mel Gibson, Heath Ledger, Joely Richardson, J...
# genres                      [Action, Drama, History, War]
# rating                                                7.2
# year                                                 2000
#
#                                                     1500   \
# plot    [Three company workers who hate their jobs dec...
# cast    [Ron Livingston, Jennifer Aniston, David Herma...
# genres                                           [Comedy]
# rating                                                7.6
# year                                                 1999
#
#                                                     1218   \
# plot    [Following the Normandy Landings, a group of U...
# cast    [Tom Hanks, Tom Sizemore, Edward Burns, Barry ...
# genres                                       [Drama, War]
# rating                                                8.6
# year                                                 1998
#
#                                                     11665  ...  \
# plot    [Set in early 19th century Romania, a policema...  ...
# cast    [Teodor Corban, Mihai Comanoiu, Toma Cuzin, Al...  ...
# genres       [Adventure, Comedy, Drama, History, Western]  ...
# rating                                                7.6  ...
# year                                                 2015  ...
#
#                                                     11201  \
# plot    [The Kerrigan - Harding incident that rocked t...
# cast    [Oksana Baiul, Mahlon Bradley, Vincent Buscemi...
# genres           [Documentary, Biography, History, Sport]
# rating                                                7.4
# year                                                 2014
#
#                                                     3481   \
# plot    [It's 1947 and the borderlines between India a...
# cast    [Aamir Khan, Nandita Das, Rahul Khanna, Maia S...
# genres                              [Drama, Romance, War]
# rating                                                7.6
# year                                                 1998
#
#                                                     13260  \
# plot    [Frank, a single man raising his child prodigy...
# cast    [Chris Evans, Mckenna Grace, Lindsay Duncan, O...
# genres                                            [Drama]
# rating                                                7.6
# year                                                 2017
#
#                                                     7259   \
# plot    [Affable hillbillies Tucker and Dale are on va...
# cast    [Tyler Labine, Alan Tudyk, Katrina Bowden, Jes...
# genres                                   [Comedy, Horror]
# rating                                                7.5
# year                                                 2010
#
#                                                     9914   \
# plot    [After having escaped the Maze, the Gladers no...
# cast    [Dylan O'Brien, Ki Hong Lee, Kaya Scodelario, ...
# genres              [Action, Adventure, Sci-Fi, Thriller]
# rating                                                6.3
# year                                                 2015
#
#                                                     1055   \
# plot    [Jeff "The Dude" Lebowski, mistaken for a mill...
# cast    [Jeff Bridges, John Goodman, Julianne Moore, S...
# genres                                    [Comedy, Crime]
# rating                                                8.1
# year                                                 1998
#
#                                                     9420   \
# plot    [A fun weekend turns into madness and horror f...
# cast    [Rachel Melvin, Cortney Palm, Lexi Atkins, Hut...
# genres                                   [Comedy, Horror]
# rating                                                4.8
# year                                                 2014
#
#                                                     8059   \
# plot    [Three magazine employees head out on an assig...
# cast    [Aubrey Plaza, Lauren Carlos, Basil Harris, Ma...
# genres       [Adventure, Comedy, Drama, Fantasy, Romance]
# rating                                                6.9
# year                                                 2012
#
#                                                     7560   \
# plot    [A young man and woman decide to take their fr...
# cast    [Justin Timberlake, Mila Kunis, Patricia Clark...
# genres                                  [Comedy, Romance]
# rating                                                6.5
# year                                                 2011
#
#                                                     7937
# plot    [A pair of underachieving cops are sent back t...
# cast    [Jonah Hill, Channing Tatum, Brie Larson, Dave...
# genres                            [Action, Comedy, Crime]
# rating                                                7.2
# year                                                 2012
#
# [5 rows x 898 columns]
